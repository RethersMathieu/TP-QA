# %% [markdown]
# # TP-QA
# ## Installation des packages
# Afin de pouvoir effectuer ce TP, nous allons installer les packages suivant:
# - **nltk**: Le "Natural Language ToolKit" (NLTK) est package python permettant de traiter le language naturel.
# - **pandas**: Pandas est un package permettant de créer et manipuler des structures de données rapides, fléxibles.
# - **sparqlwrapper**: C'est un package permettant de créer l'URI de la requête et convertir le résultat dans un format plus facile à gérer.
# - **jellyfish**: Ces un packages pour la correspondance approximative et phonétique de chaines de caractères.

# %%
# %pip install --upgrade nltk
# %pip install --upgrade pandas
# %pip install --upgrade sparqlwrapper
# %pip install --upgrade jellyfish
# Out:
# Requirement already satisfied: nltk in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (3.7)
# Requirement already satisfied: tqdm in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: joblib in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: colorama in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (1.5.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sparqlwrapper in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from sparqlwrapper) (6.2.0)
# Requirement already satisfied: isodate in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from rdflib>=6.1.1->sparqlwrapper) (0.6.1)
# Requirement already satisfied: pyparsing in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from rdflib>=6.1.1->sparqlwrapper) (3.0.9)
# Requirement already satisfied: setuptools in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from rdflib>=6.1.1->sparqlwrapper) (63.2.0)
# Requirement already satisfied: six in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (from isodate->rdflib>=6.1.1->sparqlwrapper) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: jellyfish in c:\users\bandh\appdata\local\programs\python\python310\lib\site-packages (0.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importation et téléchagement

# %%
import nltk
import re
import pandas as pd
import itertools
import jellyfish
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Bandh\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Bandh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Bandh\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# ## Importation des questions
# Les question qui nous intéresse se trouve dans un fichier **XML** dans les balises "*string*".<br><br>
# Pour cela nous allons récupérer le contenu du fichier en chaines de caractères.

# %%
doc = open("asserts/questions.xml").read()

# %% [markdown]
# Nous allons récupérer un exemplaire de question.

# %%
question = re.search('<string lang="en">(.*?)</string>', doc).group(1)
question
# Out:
# 'Which river does the Brooklyn Bridge cross?'

# %% [markdown]
# Nous récupérons les "*tokens*" de la question.

# %%
tokens = nltk.word_tokenize(question)
tokens
# Out:
# ['Which', 'river', 'does', 'the', 'Brooklyn', 'Bridge', 'cross', '?']

# %% [markdown]
# Nous récupérons une liste de tuple contenant un token (un mot) et un tag correspondant au token.

# %%
tags = nltk.pos_tag(tokens)
print(tags)
# Out:
# [('Which', 'JJ'), ('river', 'NN'), ('does', 'VBZ'), ('the', 'DT'), ('Brooklyn', 'NNP'), ('Bridge', 'NNP'), ('cross', 'NN'), ('?', '.')]

# %% [markdown]
# Récupérations de toutes les questions du fichier XML.

# %%
def getContentCDATA(s):
    reg = r'<!\[CDATA\[(.*?)]]>*'
    result = re.match(reg, s)
    if result == None: return s
    return result.group(1)

questions = re.findall(r'<string lang="en">(.*?)</string>', doc)
questions = list(map(getContentCDATA, questions))
print('\n'.join(questions))
# Out:
# Which river does the Brooklyn Bridge cross?
# Who is the author of Wikipedia?
# In which country does the Nile start?
# What is the highest place of Karakoram?
# Who designed the Brooklyn Bridge?
# Who created Goofy?
# Who is the mayor of New York City?
# Which is the source of the Yenisey river
# Which museum exhibits The Scream by Munch?
# Which states border Illinois?
# Who was the wife of U.S. president Lincoln?
# In which programming language is GIMP written?
# In which country is the Limerick Lake?
# What is the currency of the Czech Republic?
# Who developed the video game World of Warcraft?
# Who founded Aldi?
# How many employees does IBM have?
# What is the area code of Berlin?
# When was the Battle of Gettysburg?
# What is the official languages of Italy?
# Who wrote the book The Pillars of the Earth?
# Who is the author of the WikiLeaks association?
# Give me all actors starring in Last Action Hero.
# Who is the owner of Universal Studios Lot?
# Where is Bruce Carver born?

# %% [markdown]
# ## Identifier le type de réponse attendu

# %% [markdown]
# Méthode permettant de récupérer le type de la question.
# - when
# - who
# - where
# - what
# - how

# %%
def indentify(question):
    types = (
        ('when', 'when'),
        ('who', 'who'),
        ('where', 'where'),
        ('what', 'what'), ('how', 'how'), ('in which', 'where'), ('which', 'what'))
    for (regex, type) in types:
        if re.search(regex, question, re.IGNORECASE):
            return type
    return None

# %%
types_questions = [(indentify(question), question) for question in questions]
pd.DataFrame(types_questions, columns=['Type', 'Question'])
# Out:
#      Type                                          Question
# 0    what       Which river does the Brooklyn Bridge cross?
# 1     who                   Who is the author of Wikipedia?
# 2   where             In which country does the Nile start?
# 3    what           What is the highest place of Karakoram?
# 4     who                 Who designed the Brooklyn Bridge?
# 5     who                                Who created Goofy?
# 6     who                Who is the mayor of New York City?
# 7    what          Which is the source of the Yenisey river
# 8    what        Which museum exhibits The Scream by Munch?
# 9    what                     Which states border Illinois?
# 10    who       Who was the wife of U.S. president Lincoln?
# 11  where    In which programming language is GIMP written?
# 12  where            In which country is the Limerick Lake?
# 13   what       What is the currency of the Czech Republic?
# 14    who   Who developed the video game World of Warcraft?
# 15    who                                 Who founded Aldi?
# 16    how                 How many employees does IBM have?
# 17   what                  What is the area code of Berlin?
# 18   when                When was the Battle of Gettysburg?
# 19   what          What is the official languages of Italy?
# 20    who      Who wrote the book The Pillars of the Earth?
# 21    who   Who is the author of the WikiLeaks association?
# 22   None  Give me all actors starring in Last Action Hero.
# 23    who        Who is the owner of Universal Studios Lot?
# 24  where                       Where is Bruce Carver born?

# %% [markdown]
# ## Récupérations des NNP

# %%
questions_tokens = list(map(nltk.word_tokenize, questions))
questions_tags = list(map(nltk.pos_tag, questions_tokens))

# %%
def get_NNP(question):
    GRAMMAR_NP = r"""
    NP: {<NNP>+}
        {<DT><NN>}
  """
    tokens = nltk.word_tokenize(question)
    tags = nltk.pos_tag(tokens)
    cp = nltk.RegexpParser(GRAMMAR_NP)
    tree = cp.parse(tags)

    RESULTS = []
    for i in tree.subtrees(filter=lambda x: x.label() == 'NP'):
        NPS = [word for (word, _) in i if not re.match('which', word, re.IGNORECASE)]
        RESULTS.append("_".join(NPS))
    return list(filter(lambda value: value, RESULTS))

# %%
NNPs_questions = zip(questions, [get_NNP(question) for question in questions])
pd.DataFrame(NNPs_questions, columns=['Question', "NNP"])
# Out:
#                                             Question  \
# 0        Which river does the Brooklyn Bridge cross?
# 1                    Who is the author of Wikipedia?
# 2              In which country does the Nile start?
# 3            What is the highest place of Karakoram?
# 4                  Who designed the Brooklyn Bridge?
# 5                                 Who created Goofy?
# 6                 Who is the mayor of New York City?
# 7           Which is the source of the Yenisey river
# 8         Which museum exhibits The Scream by Munch?
# 9                      Which states border Illinois?
# 10       Who was the wife of U.S. president Lincoln?
# 11    In which programming language is GIMP written?
# 12            In which country is the Limerick Lake?
# 13       What is the currency of the Czech Republic?
# 14   Who developed the video game World of Warcraft?
# 15                                 Who founded Aldi?
# 16                 How many employees does IBM have?
# 17                  What is the area code of Berlin?
# 18                When was the Battle of Gettysburg?
# 19          What is the official languages of Italy?
# 20      Who wrote the book The Pillars of the Earth?
# 21   Who is the author of the WikiLeaks association?
# 22  Give me all actors starring in Last Action Hero.
# 23        Who is the owner of Universal Studios Lot?
# 24                       Where is Bruce Carver born?
#
#                                    NNP
# 0                    [Brooklyn_Bridge]
# 1              [the_author, Wikipedia]
# 2                               [Nile]
# 3                          [Karakoram]
# 4                    [Brooklyn_Bridge]
# 5                              [Goofy]
# 6           [the_mayor, New_York_City]
# 7                [the_source, Yenisey]
# 8                  [The_Scream, Munch]
# 9                           [Illinois]
# 10           [the_wife, U.S., Lincoln]
# 11                              [GIMP]
# 12                     [Limerick_Lake]
# 13      [the_currency, Czech_Republic]
# 14        [the_video, World, Warcraft]
# 15                              [Aldi]
# 16                               [IBM]
# 17                  [the_area, Berlin]
# 18                [Battle, Gettysburg]
# 19                             [Italy]
# 20          [the_book, Pillars, Earth]
# 21             [the_author, WikiLeaks]
# 22                       [Action_Hero]
# 23  [the_owner, Universal_Studios_Lot]
# 24                      [Bruce_Carver]

# %% [markdown]
# ## Extraction des relations

# %%
def extract_relations(path: str):
    f_read = open(f'{path}.txt', 'r').read()

    def get(pattern, array):
        res = re.findall(pattern, array)
        return [value.strip() for value in res]

    def typage(type, value):
        return (type, value.strip())
    relation_DBO = get('dbo:(.+?)\n', f_read)
    relation_DBP = get('dbp:(.+?)\n', f_read)
    res = [typage('dbo', value) for value in relation_DBO] + \
        [typage('dbp', value) for value in relation_DBP]
    return res

# %%
relations = extract_relations('asserts/relations')
pd.DataFrame(relations, columns=['Type', 'Nom'])
# Out:
#    Type                  Nom
# 0   dbo                album
# 1   dbo             areaCode
# 2   dbo               author
# 3   dbo               battle
# 4   dbo            birthDate
# 5   dbo           birthPlace
# 6   dbo              capital
# 7   dbo                child
# 8   dbo                 city
# 9   dbo              country
# 10  dbo              creator
# 11  dbo              crosses
# 12  dbo             currency
# 13  dbo           deathCause
# 14  dbo            deathDate
# 15  dbo           deathPlace
# 16  dbo            developer
# 17  dbo             director
# 18  dbo            elevation
# 19  dbo        formationYear
# 20  dbo            foundedBy
# 21  dbo      foundationPlace
# 22  dbo         foundingYear
# 23  dbo                genre
# 24  dbo       governmentType
# 25  dbo               ground
# 26  dbo               height
# 27  dbo              highest
# 28  dbo             isPartOf
# 29  dbo            keyPerson
# 30  dbo             language
# 31  dbo          largestCity
# 32  dbo               league
# 33  dbo        locatedInArea
# 34  dbo             location
# 35  dbo    numberOfEmployees
# 36  dbo     officialLanguage
# 37  dbo             operator
# 38  dbo        orderInOffice
# 39  dbo                owner
# 40  dbo             producer
# 41  dbo  programmingLanguage
# 42  dbo            publisher
# 43  dbo         seasonNumber
# 44  dbo               series
# 45  dbo             spokenIn
# 46  dbo               spouse
# 47  dbo             starring
# 48  dbp                 date
# 49  dbp           leaderName
# 50  dbp               source
# 51  dbp      source2Location
# 52  dbp               awards
# 53  dbp      borderingstates
# 54  dbp              country
# 55  dbp               museum
# 56  dbp             starring
# 57  dbp             designer

# %% [markdown]
# ## Récupération des synonymes des relations

# %%
def join_synsets(separators: list[str], word: str):
    from nltk.corpus import wordnet
    word_splited = re.findall('[a-zA-Z][^A-Z]*', word)
    words = [separator.join(word_splited).lower() for separator in separators]
    array_synsets = [wordnet.synsets(item) for item in words]
    array_synsets = list(itertools.chain.from_iterable(array_synsets))
    array_synsets = list(dict.fromkeys(array_synsets))
    return array_synsets

# %%
def get_dict_synonyms(relations: list[(str, str)]) -> dict:
    d = {}
    for type, word in relations:
        d[(type, word)] = join_synsets(['', ' ', '-', '_', '.', ';'], word)
    return d

# %%
dict_synonyms = get_dict_synonyms(relations)
relations_synonyms = [(f'{type}:{relation}', synsets) for (type, relation), synsets in dict_synonyms.items()]
pd.DataFrame(relations_synonyms, columns=['Relation', 'Synsets'])
# Out:
#                    Relation                                            Synsets
# 0                 dbo:album       [Synset('album.n.01'), Synset('album.n.02')]
# 1              dbo:areaCode                         [Synset('area_code.n.01')]
# 2                dbo:author  [Synset('writer.n.01'), Synset('generator.n.03...
# 3                dbo:battle  [Synset('battle.n.01'), Synset('struggle.n.01'...
# 4             dbo:birthDate                                                 []
# 5            dbo:birthPlace  [Synset('birthplace.n.01'), Synset('birthplace...
# 6               dbo:capital  [Synset('capital.n.01'), Synset('capital.n.02'...
# 7                 dbo:child  [Synset('child.n.01'), Synset('child.n.02'), S...
# 8                  dbo:city  [Synset('city.n.01'), Synset('city.n.02'), Syn...
# 9               dbo:country  [Synset('state.n.04'), Synset('country.n.02'),...
# 10              dbo:creator   [Synset('godhead.n.01'), Synset('creator.n.02')]
# 11              dbo:crosses  [Synset('crosse.n.01'), Synset('cross.n.01'), ...
# 12             dbo:currency  [Synset('currency.n.01'), Synset('currency.n.0...
# 13           dbo:deathCause                                                 []
# 14            dbo:deathDate                                                 []
# 15           dbo:deathPlace                                                 []
# 16            dbo:developer  [Synset('developer.n.01'), Synset('developer.n...
# 17             dbo:director  [Synset('director.n.01'), Synset('director.n.0...
# 18            dbo:elevation  [Synset('elevation.n.01'), Synset('acme.n.01')...
# 19        dbo:formationYear                                                 []
# 20            dbo:foundedBy                                                 []
# 21      dbo:foundationPlace                                                 []
# 22         dbo:foundingYear                                                 []
# 23                dbo:genre  [Synset('genre.n.01'), Synset('writing_style.n...
# 24       dbo:governmentType                                                 []
# 25               dbo:ground  [Synset('land.n.04'), Synset('reason.n.01'), S...
# 26               dbo:height  [Synset('height.n.01'), Synset('acme.n.01'), S...
# 27              dbo:highest  [Synset('high.a.01'), Synset('high.a.02'), Syn...
# 28             dbo:isPartOf                                                 []
# 29            dbo:keyPerson                                                 []
# 30             dbo:language  [Synset('language.n.01'), Synset('speech.n.02'...
# 31          dbo:largestCity                                                 []
# 32               dbo:league  [Synset('league.n.01'), Synset('league.n.02'),...
# 33        dbo:locatedInArea                                                 []
# 34             dbo:location  [Synset('location.n.01'), Synset('placement.n....
# 35    dbo:numberOfEmployees                                                 []
# 36     dbo:officialLanguage                                                 []
# 37             dbo:operator  [Synset('operator.n.01'), Synset('operator.n.0...
# 38        dbo:orderInOffice                                                 []
# 39                dbo:owner       [Synset('owner.n.01'), Synset('owner.n.02')]
# 40             dbo:producer  [Synset('manufacturer.n.02'), Synset('producer...
# 41  dbo:programmingLanguage              [Synset('programming_language.n.01')]
# 42            dbo:publisher  [Synset('publisher.n.01'), Synset('publisher.n...
# 43         dbo:seasonNumber                                                 []
# 44               dbo:series  [Synset('series.n.01'), Synset('serial.n.01'),...
# 45             dbo:spokenIn                                                 []
# 46               dbo:spouse                            [Synset('spouse.n.01')]
# 47             dbo:starring  [Synset('star.v.01'), Synset('star.v.02'), Syn...
# 48                 dbp:date  [Synset('date.n.01'), Synset('date.n.02'), Syn...
# 49           dbp:leaderName                                                 []
# 50               dbp:source  [Synset('beginning.n.04'), Synset('source.n.02...
# 51      dbp:source2Location                                                 []
# 52               dbp:awards  [Synset('award.n.01'), Synset('award.n.02'), S...
# 53      dbp:borderingstates                                                 []
# 54              dbp:country  [Synset('state.n.04'), Synset('country.n.02'),...
# 55               dbp:museum                            [Synset('museum.n.01')]
# 56             dbp:starring  [Synset('star.v.01'), Synset('star.v.02'), Syn...
# 57             dbp:designer  [Synset('interior_designer.n.01'), Synset('arc...

# %% [markdown]
# ## Récupération des réponses des question
# Méthode permettant de trouver la relations la plus proche de la question inséré en paramètre.<br>
# Pour cela, nous utilisons la méthode de *jara_similarity* du package **jellyfish**

# %%
def get_relation_by_distance(token_question: list[str], relations: list[(str, str)]):
    import sys
    dis_max = sys.float_info.min
    relation = None
    for word in token_question:
        for (type, name) in relations:
            dis = jellyfish.jaro_similarity(word, name)
            if dis > dis_max:
                dis_max = dis
                relation = (type, name)
    return relation

# %% [markdown]
# Mise en relations des questions et des relations.

# %%
questions_relations = [(get_relation_by_distance(qt, relations), qt) for qt in questions_tokens]
pd.DataFrame([(f'{type}:{name}', ' '.join(qt)) for (type, name), qt in questions_relations], columns=['Relation', 'Question'])
# Out:
#                 Relation                                           Question
# 0            dbo:crosses       Which river does the Brooklyn Bridge cross ?
# 1             dbo:author                   Who is the author of Wikipedia ?
# 2            dbo:country             In which country does the Nile start ?
# 3            dbo:highest           What is the highest place of Karakoram ?
# 4           dbp:designer                 Who designed the Brooklyn Bridge ?
# 5            dbo:creator                                Who created Goofy ?
# 6               dbo:city                Who is the mayor of New York City ?
# 7             dbp:source           Which is the source of the Yenisey river
# 8             dbp:museum        Which museum exhibits The Scream by Munch ?
# 9    dbp:borderingstates                     Which states border Illinois ?
# 10            dbo:series       Who was the wife of U.S. president Lincoln ?
# 11          dbo:language    In which programming language is GIMP written ?
# 12           dbo:country            In which country is the Limerick Lake ?
# 13          dbo:currency       What is the currency of the Czech Republic ?
# 14         dbo:developer   Who developed the video game World of Warcraft ?
# 15         dbo:foundedBy                                 Who founded Aldi ?
# 16          dbp:designer                 How many employees does IBM have ?
# 17          dbo:areaCode                  What is the area code of Berlin ?
# 18            dbo:battle                When was the Battle of Gettysburg ?
# 19          dbo:language          What is the official languages of Italy ?
# 20  dbo:officialLanguage      Who wrote the book The Pillars of the Earth ?
# 21            dbo:author   Who is the author of the WikiLeaks association ?
# 22          dbo:starring  Give me all actors starring in Last Action Hero .
# 23             dbo:owner        Who is the owner of Universal Studios Lot ?
# 24          dbo:producer                       Where is Bruce Carver born ?

# %% [markdown]
# Méthode permettant de créer les requêtes à envoyer à *dbpedia*.

# %%
def create_request(type_relation, relation, NNP):
    link = 'http://dbpedia.org/ontology/' if type_relation == 'dbo' else 'http://dbpedia.org/property/'
    return """
    PREFIX %s: <%s>
    PREFIX res: <http://dbpedia.org/resource/>
    SELECT DISTINCT ?uri WHERE {
        res:%s %s ?uri .
    }
    """ % (type_relation, link, NNP.replace(' ', '_'), f'{type_relation}:{relation}')

# %% [markdown]
# Méthode permettant d'avoir seulement le premier contenue d'une liste.

# %%
def get_first(array: list[str]) -> str:
    if (len(array) > 0):
        return array[0]
    return ''

# %% [markdown]
# Créations des requetes par rapport aux relations et aux questions.

# %%
requests = [create_request(type, name, get_first(get_NNP(' '.join(qt)))) for (type, name), qt in questions_relations]
f'Nombre de requete : {len(requests)}'
# Out:
# 'Nombre de requete : 25'

# %% [markdown]
# Création de l'objet *SPARQLWrapper* qui permettra d'envoyé les requetes et de recevoir les réponses (en format JSON) au server de **DBPedia**.

# %%
def Sparql():
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    sparql.setReturnFormat(JSON)
    return sparql
sparql = Sparql()

# %% [markdown]
# Méthodes permettant d'obtenir les reponses d'une requêtes à partir d'un *SPARQLWrapper*.

# %%
def getResponses(sparql, quest):
    sparql.setQuery(quest)
    sparql.query()
    ret: dict = sparql.queryAndConvert()
    responses = []
    if ('results' in ret and 'bindings' in ret['results']):
        for r in ret['results']['bindings']:
            if ('uri' in r and 'value' in r['uri']):
                responses.append(r['uri']['value'])
    return responses

# %% [markdown]
# Méthode permettant de remplacer les contenue vide par *None*.

# %%
def replace_values_empty(array):
    for index in range(len(array)):
        value = array[index]
        if not value:
            array[index] = None

# %% [markdown]
# Envoie des requetes à **DBPedia** et récupérations des réponses.

# %%
responses = [getResponses(sparql, q) for q in requests]
replace_values_empty(responses)
questions_responses = zip(questions, responses)
pd.DataFrame(questions_responses, columns=['Questions', 'Reponses'])
# Out:
#                                            Questions  \
# 0        Which river does the Brooklyn Bridge cross?
# 1                    Who is the author of Wikipedia?
# 2              In which country does the Nile start?
# 3            What is the highest place of Karakoram?
# 4                  Who designed the Brooklyn Bridge?
# 5                                 Who created Goofy?
# 6                 Who is the mayor of New York City?
# 7           Which is the source of the Yenisey river
# 8         Which museum exhibits The Scream by Munch?
# 9                      Which states border Illinois?
# 10       Who was the wife of U.S. president Lincoln?
# 11    In which programming language is GIMP written?
# 12            In which country is the Limerick Lake?
# 13       What is the currency of the Czech Republic?
# 14   Who developed the video game World of Warcraft?
# 15                                 Who founded Aldi?
# 16                 How many employees does IBM have?
# 17                  What is the area code of Berlin?
# 18                When was the Battle of Gettysburg?
# 19          What is the official languages of Italy?
# 20      Who wrote the book The Pillars of the Earth?
# 21   Who is the author of the WikiLeaks association?
# 22  Give me all actors starring in Last Action Hero.
# 23        Who is the owner of Universal Studios Lot?
# 24                       Where is Bruce Carver born?
#
#                                              Reponses
# 0            [http://dbpedia.org/resource/East_River]
# 1                                                None
# 2                                                None
# 3                    [http://dbpedia.org/resource/K2]
# 4   [http://dbpedia.org/resource/John_Augustus_Roe...
# 5   [http://dbpedia.org/resource/Bob_Ogle, http://...
# 6                                                None
# 7                                                None
# 8                 [National Gallery and Munch Museum]
# 9   [http://dbpedia.org/resource/Kentucky, http://...
# 10                                               None
# 11  [http://dbpedia.org/resource/Amharic, http://d...
# 12               [http://dbpedia.org/resource/Canada]
# 13                                               None
# 14                                               None
# 15  [http://dbpedia.org/resource/Theo_Albrecht, ht...
# 16                                               None
# 17                                               None
# 18                                               None
# 19   [http://dbpedia.org/resource/Languages_of_Italy]
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None

# %% [markdown]
# ## Vérification des réponses

# %% [markdown]
# Afin de vérifie la fibilité des résultats de nos requetes nous allons les comparés aux requêtes enregistré dans le XML.<br>
# Pour cela nous allons récupérer les requetes contenue dans les balises *query*.

# %%
queries = re.findall('<query>(.*?)</query>', doc, re.DOTALL)
queries = [query.replace('\n', "") for query in queries]
queries = list(map(getContentCDATA, queries))
f'Nombre de requete trouver dans le XML : {len(queries)}'
# Out:
# 'Nombre de requete trouver dans le XML : 25'

# %% [markdown]
# Récupérations des reponses.

# %%
responses_waiting = [getResponses(sparql, q) for q in queries]
replace_values_empty(responses_waiting)
questions_responses_waiting = zip(questions, responses_waiting)
pd.DataFrame(questions_responses_waiting, columns=['Questions', 'Reponses'])
# Out:
#                                            Questions  \
# 0        Which river does the Brooklyn Bridge cross?
# 1                    Who is the author of Wikipedia?
# 2              In which country does the Nile start?
# 3            What is the highest place of Karakoram?
# 4                  Who designed the Brooklyn Bridge?
# 5                                 Who created Goofy?
# 6                 Who is the mayor of New York City?
# 7           Which is the source of the Yenisey river
# 8         Which museum exhibits The Scream by Munch?
# 9                      Which states border Illinois?
# 10       Who was the wife of U.S. president Lincoln?
# 11    In which programming language is GIMP written?
# 12            In which country is the Limerick Lake?
# 13       What is the currency of the Czech Republic?
# 14   Who developed the video game World of Warcraft?
# 15                                 Who founded Aldi?
# 16                 How many employees does IBM have?
# 17                  What is the area code of Berlin?
# 18                When was the Battle of Gettysburg?
# 19          What is the official languages of Italy?
# 20      Who wrote the book The Pillars of the Earth?
# 21   Who is the author of the WikiLeaks association?
# 22  Give me all actors starring in Last Action Hero.
# 23        Who is the owner of Universal Studios Lot?
# 24                       Where is Bruce Carver born?
#
#                                              Reponses
# 0            [http://dbpedia.org/resource/East_River]
# 1                                                None
# 2                                                None
# 3                                                None
# 4   [http://dbpedia.org/resource/John_Augustus_Roe...
# 5                                                None
# 6                                                None
# 7   [http://dbpedia.org/resource/Ka-Hem, The most ...
# 8                                                None
# 9   [http://dbpedia.org/resource/Kentucky, http://...
# 10    [http://dbpedia.org/resource/Mary_Todd_Lincoln]
# 11  [http://dbpedia.org/resource/C_(programming_la...
# 12               [http://dbpedia.org/resource/Canada]
# 13                                               None
# 14  [http://dbpedia.org/resource/Blizzard_Entertai...
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20          [http://dbpedia.org/resource/Ken_Follett]
# 21                                               None
# 22  [http://dbpedia.org/resource/Art_Carney, http:...
# 23                                               None
# 24                                               None

# %% [markdown]
# ## Conclusion
# Comme nous pouvons le voir, certains résultats corresponde mais une grosse partie sont fausse entre eux.<br>
# Cela peut s'expliquer par le fait que les relations ont été mis à jour et que les requetes dans le XML ne sont pas à jour.

# %%
results = zip(questions, responses_waiting, responses)
pd.DataFrame(results, columns=['Questions', 'Réponses attendues', 'Réponses'])
# Out:
#                                            Questions  \
# 0        Which river does the Brooklyn Bridge cross?
# 1                    Who is the author of Wikipedia?
# 2              In which country does the Nile start?
# 3            What is the highest place of Karakoram?
# 4                  Who designed the Brooklyn Bridge?
# 5                                 Who created Goofy?
# 6                 Who is the mayor of New York City?
# 7           Which is the source of the Yenisey river
# 8         Which museum exhibits The Scream by Munch?
# 9                      Which states border Illinois?
# 10       Who was the wife of U.S. president Lincoln?
# 11    In which programming language is GIMP written?
# 12            In which country is the Limerick Lake?
# 13       What is the currency of the Czech Republic?
# 14   Who developed the video game World of Warcraft?
# 15                                 Who founded Aldi?
# 16                 How many employees does IBM have?
# 17                  What is the area code of Berlin?
# 18                When was the Battle of Gettysburg?
# 19          What is the official languages of Italy?
# 20      Who wrote the book The Pillars of the Earth?
# 21   Who is the author of the WikiLeaks association?
# 22  Give me all actors starring in Last Action Hero.
# 23        Who is the owner of Universal Studios Lot?
# 24                       Where is Bruce Carver born?
#
#                                    Réponses attendues  \
# 0            [http://dbpedia.org/resource/East_River]
# 1                                                None
# 2                                                None
# 3                                                None
# 4   [http://dbpedia.org/resource/John_Augustus_Roe...
# 5                                                None
# 6                                                None
# 7   [http://dbpedia.org/resource/Ka-Hem, The most ...
# 8                                                None
# 9   [http://dbpedia.org/resource/Kentucky, http://...
# 10    [http://dbpedia.org/resource/Mary_Todd_Lincoln]
# 11  [http://dbpedia.org/resource/C_(programming_la...
# 12               [http://dbpedia.org/resource/Canada]
# 13                                               None
# 14  [http://dbpedia.org/resource/Blizzard_Entertai...
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20          [http://dbpedia.org/resource/Ken_Follett]
# 21                                               None
# 22  [http://dbpedia.org/resource/Art_Carney, http:...
# 23                                               None
# 24                                               None
#
#                                              Réponses
# 0            [http://dbpedia.org/resource/East_River]
# 1                                                None
# 2                                                None
# 3                    [http://dbpedia.org/resource/K2]
# 4   [http://dbpedia.org/resource/John_Augustus_Roe...
# 5   [http://dbpedia.org/resource/Bob_Ogle, http://...
# 6                                                None
# 7                                                None
# 8                 [National Gallery and Munch Museum]
# 9   [http://dbpedia.org/resource/Kentucky, http://...
# 10                                               None
# 11  [http://dbpedia.org/resource/Amharic, http://d...
# 12               [http://dbpedia.org/resource/Canada]
# 13                                               None
# 14                                               None
# 15  [http://dbpedia.org/resource/Theo_Albrecht, ht...
# 16                                               None
# 17                                               None
# 18                                               None
# 19   [http://dbpedia.org/resource/Languages_of_Italy]
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
